# %%
import numpy as np

# %%
import pandas as pd

# %%
results = pd.read_csv('../../data/primary-results.csv')

# %%
results.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
len(results)
# Out:
# 24611

# %%
results.groupby('candidate')

# %%
results.groupby('candidate').aggregate({'votes':[min, np.mean, max]})
# Out:
#                 votes
#                   min         mean     max
# candidate
#  No Preference      0    23.225071     580
#  Uncommitted        0     0.434343      16
# Ben Carson          0   338.258238    9945
# Bernie Sanders      0  2844.019501  434656
# Carly Fiorina       0   139.366972    3612
# Chris Christie      1   223.422018    7144
# Donald Trump        0  3709.576408  179130
# Hillary Clinton     0  3731.855410  590502
# Jeb Bush            2   609.103226    9575
# John Kasich         0  1160.052705  101217
# Marco Rubio         0  1299.834051  111898
# Martin O'Malley     0     7.595960     152
# Mike Huckabee       2    33.787879     565
# Rand Paul           2    85.646465    1633
# Rick Santorum       0    18.000000     234
# Ted Cruz            0  2120.191299  147721

# %%
#Em qual luga a Hillary Clinton não teve votos
results[(results['votes'] == 0) & (results['candidate'] == 'Hillary Clinton')]
# Out:
#                state state_abbreviation                    county        fips  \
# 476           Alaska                 AK   State House District 12  90200112.0
# 500           Alaska                 AK   State House District 23  90200123.0
# 514           Alaska                 AK    State House District 3  90200103.0
# 518           Alaska                 AK   State House District 31  90200131.0
# 520           Alaska                 AK   State House District 32  90200132.0
# 532           Alaska                 AK   State House District 38  90200138.0
# 538           Alaska                 AK   State House District 40  90200140.0
# 540           Alaska                 AK    State House District 5  90200105.0
# 542           Alaska                 AK    State House District 6  90200106.0
# 546           Alaska                 AK    State House District 8  90200108.0
# 839         Arkansas                 AR                   Carroll      5015.0
# ...

# %%
def votes_filter(x):
    return x['votes'].sum() > 300000
results.groupby('state').filter(votes_filter)
# Out:
#            state state_abbreviation      county     fips       party  \
# 0        Alabama                 AL     Autauga   1001.0    Democrat
# 1        Alabama                 AL     Autauga   1001.0    Democrat
# 2        Alabama                 AL     Baldwin   1003.0    Democrat
# 3        Alabama                 AL     Baldwin   1003.0    Democrat
# 4        Alabama                 AL     Barbour   1005.0    Democrat
# 5        Alabama                 AL     Barbour   1005.0    Democrat
# 6        Alabama                 AL        Bibb   1007.0    Democrat
# 7        Alabama                 AL        Bibb   1007.0    Democrat
# 8        Alabama                 AL      Blount   1009.0    Democrat
# 9        Alabama                 AL      Blount   1009.0    Democrat
# 10       Alabama                 AL     Bullock   1011.0    Democrat
# 11       Alabama                 AL     Bullock   1011.0    Democrat
# 12       Alabama                 AL      Butler   1013.0    Democrat
# ...

# %%
results.groupby(['state_abbreviation', 'candidate'])['state'].sum()
# Out:
# state_abbreviation  candidate
# AK                  Ben Carson         AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     Bernie Sanders     AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     Donald Trump       AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     Hillary Clinton    AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     John Kasich        AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     Marco Rubio        AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
#                     Ted Cruz           AlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlaskaAlas...
# AL                  Ben Carson         AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
#                     Bernie Sanders     AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
#                     Donald Trump       AlabamaAlabamaAlabamaAlabamaAlabamaAlabamaAlab...
# ...
